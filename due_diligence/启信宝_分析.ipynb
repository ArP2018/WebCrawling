# %%
import requests

# %%
URL = 'https://www.qixin.com/search?key=%E5%BE%B7%E5%8B%A4'
cookie = 'channel=baidu; aliyungf_tc=AQAAACLJeHAHhAEAwMG23sZoOg+ewrXX; acw_tc=707c9fdb15589455791113318e0db72e73c9e5db6f5e7a0b9399089f8eb411; acw_sc__v2=5ceb9f2b74e1ab191137962caca25ae19e76639f; Hm_lvt_52d64b8d3f6d42a2e416d59635df3f71=1558945582; cookieShowLoginTip=1; sid=s%3AkHkXoouE04mGNVg70TM917m4shAl7zVQ.cZUfcAIsAcsB9dz95VWor95QxsdoGCXLew9EUr1bKs0; Hm_lpvt_52d64b8d3f6d42a2e416d59635df3f71=1558946387'
header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3423.2 Safari/537.36',
    'cookie': cookie
}

# %%
resp = requests.get(URL, headers=header)

# %%
resp.text
# Out:
# '<!DOCTYPE html><html lang="zh-CN"><head><meta charset="utf-8"><meta name="baidu-site-verification" content="QyPoUuVwwf"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="format-detection" content="telephone=no,email=no,address=no"><meta name="viewport" content="width=device-width, initial-scale=1"><link href="/favicon.ico" rel="icon" type="image/x-icon"><title>【德勤】了解更多德勤相关企业信息和个人信用信息-启信宝.</title><meta name="description" content="启信宝提供企业信用信息查询服务,了解更多德勤相关企业信息和个人信用信息,就上启信宝."><meta name="keywords" content="德勤,德勤信息查询,个人信用信息查询,企业工商信息查询,天眼查,企查查."><link rel="stylesheet" href="//cache.qixin.com/pcweb/common.6413f023.css"><link rel="stylesheet" href="//cache.qixin.com/pcweb/search_enterprise.6413f023.css"><script>\r\n    (function () {\r\n      var hm = document.createElement("script");\r\n      hm.src = "//hm.baidu.com/hm.js?52d64b8d3f6d42a2e416d59635df3f71";\r\n      var s = document.getElementsByTagName("script")[0];\r\n      s.parentNode.insertBefore(hm, s);\r\n    })();\r\
# ...
