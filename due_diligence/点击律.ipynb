# %%
# 点击律

URL = 'http://www.51djl.com/enterprise/judge'
COOKIE = 'ruri=2bc05308-0d83-4190-81f2-83e47b6dc754-c9a64e37-85f9-4c55-b4c5-ce7f94ae2847; UM_distinctid=169a4268cb62-0bcdccae437724-675c772b-144600-169a4268cb7467; CNZZDATA1258139872=1835552072-1553236495-null%7C1553236495; i=114117479017480192; u=%E5%B0%B9%E9%BB%98; r=0; v=0; t=eyJraWQiOiJqd2siLCJhbGciOiJIUzUxMiJ9.eyJpc3MiOiJhdXRoLjUxZGpsLmNvbSIsImF1ZCI6IjExNDExNzQ3OTAxNzQ4MDE5MiIsImV4cCI6MTU1MzI4MDUwOCwianRpIjoiYVptdVltSGE3bE1GeTNhdlpRdW1xUSIsImlhdCI6MTU1MzIzNzMwOCwic3ViIjoic3ViamVjdCIsImFwcCI6IndlYiJ9.3GL2Kg6PNBKNQnNwCwf29G_S_gcXgxXNY8IYJPNuJExJUjMo3TTFv67p9r6lvuJZrMKz5Dp-Mb_vx7TjxB2kXg'
HEADER = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3423.2 Safari/537.36',
    'host': 'www.51djl.com',
    'referer': 'http://www.51djl.com/enterprise/query',
    'cookie': COOKIE
}

# %%
import requests

# %%
resp = requests.post(URL, data={'enterpriseName': '邯钢集团邯宝钢铁有限公司'}, headers=HEADER).json()

# %%
[i for i in resp.get('info')]
# Out:
# [{'k': '18460231010877559', 'v': '邯钢集团邯宝钢铁有限公司'}]

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(requests.get('http://www.51djl.com/enterprise/18460231010877559', headers=HEADER).text, 'lxml')

# %%
import re
re.findall(re.compile('可以查看(\S*)的涉案金额'),  soup.find('meta', attrs={'name':'description'}).attrs['content'])[0]
# Out:
# '6b747473666f6c647a3cea81b0e893a1ea9a87e49ca1ea81b0e4af9cea91a3e89480e79b8ae89a8fe684ade490b7'

# %%
case_json =requests.post('http://www.51djl.com/enterprise/credit/caseSummary', data={'enterpriseName':'6b747473666f6c647a3cea81b0e893a1ea9a87e49ca1ea81b0e4af9cea91a3e89480e79b8ae89a8fe684ade490b7'},headers=HEADER).json()

# %%
case_json
# Out:
# {'code': 1,
#  'msg': None,
#  'info': {'plaintiffCaseAmount': 0,
#   'plaintiffCaseSum': 0.0,
#   'defendantCaseAmount': 23,
#   'defendantCaseSum': 36722288.0,
#   'otherCaseAmount': 4,
#   'allResult': True,
#   'otherCaseSum': 51467466.0,
#   'caseInfos': [{'caseId': '1333224',
#     'caseTitle': '上诉人李国海与中信公司、邯宝公司、）信德公司、三冶安装公司建设工程承包合同纠纷二审民事裁定书',
#     'caseCode': '（2012）邯市立民终字第40号',
#     'uri': '0/325/2024/bafff6e4-a45d-4cb1-bd19-f00e48ab64f9.html',
#     'category': '合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': -1.0,
#     'caseDate': '2012-02-15 00:00:00',
#     'caseCourt': '河北省邯郸市中级人民法院'},
#    {'caseId': '1680480',
#     'caseTitle': '原告河北永胜石油化工机械制造有限公司与被告邯郸钢铁集团邯宝有限公司、河北安丰贸易有限公司、邯郸市瑞安达物资有限公司票据返还请求权纠纷一审民事裁定书',
#     'caseCode': '（2012）复民初第1637号',
#     'uri': '0/410/1120/b7483f9c-73d2-45dd-9040-e109edb721a4.html',
#     'category': '票据返还请求权纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 111000.0,
#     'caseDate': '2012-07-09 00:00:00',
#     'caseCourt': '邯郸市复兴区人民法院'},
#    {'caseId': '1864127',
#     'caseTitle': '上海宝源钢国际贸易有限公司与远大物产集团有限公司委托合同纠纷一审民事判决书',
#     'caseCode': '（2013）甬东商初字第387号',
#     'uri': '0/455/447/22cee794-1a41-4411-80bb-8f936cf5fb4a.html',
#     'category': '委托合同纠纷',
#     'caseType': 1,
#     'role': 2,
#     'amount': 1456666.0,
#     'caseDate': '2014-03-05 00:00:00',
#     'caseCourt': '宁波市江东区人民法院'},
#    {'caseId': '2116475',
#     'caseTitle': '北京宇诚联合科技有限公司与邯钢集团邯宝钢铁有限公司买卖合同纠纷一审民事裁定书',
#     'caseCode': '（2014）复民初字第80号',
#     'uri': '0/516/2939/908ad444-e009-429d-a49e-b5f252fd3b90.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 161000.0,
#     'caseDate': '2014-04-15 00:00:00',
#     'caseCourt': '邯郸市复兴区人民法院'},
#    {'caseId': '2885317',
#     'caseTitle': '原告福建上润精密仪器有限公司诉被告邯钢集团邯宝钢铁有限公司买卖合同纠纷一案一审民事裁定书',
#     'caseCode': '（2014）复民初字第776号',
#     'uri': '0/704/1733/729c362a-022e-4bc7-9e53-8e07cd37a246.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 211333.0,
#     'caseDate': '2014-11-27 00:00:00',
#     'caseCourt': '邯郸市复兴区人民法院'},
#    {'caseId': '7646141',
#     'caseTitle': '上海凯泉泵业（集团）有限公司与邯钢集团邯宝钢铁有限公司纠纷一案一审民事裁定书',
#     'caseCode': '（2013）复民初字第1516号',
#     'uri': '0/1866/3005/32e37a45-0280-4b1f-b39e-a098ad2e6d00.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 253000.0,
#     'caseDate': '2013-12-09 00:00:00',
#     'caseCourt': '邯郸市复兴区人民法院'},
#    {'caseId': '39197686',
#     'caseTitle': '营口中润节能环保科技发展有限公司与邯钢集团邯宝钢铁有限公司买卖合同纠纷一审民事裁定书',
#     'caseCode': '（2016）冀0404民初2063号',
#     'uri': '0/2/1377/5783f848-04d9-4fe5-b2c3-5c43d1f2fff2.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 188000.0,
#     'caseDate': '2016-09-12 00:00:00',
#     'caseCourt': '邯郸市复兴区人民法院'},
#    {'caseId': '39212829',
#     'caseTitle': '自贡红运逆止器机械制造有限公司与邯钢集团邯宝钢铁有限公司买卖合同纠纷一审民事裁定书',
#     'caseCode': '（2016）冀0404民初2071号',
#     'uri': '0/2/1381/14ee280f-7f9a-4fc8-821a-40f063e3cf3d.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 121000.0,
#     'caseDate': '2016-09-21 00:00:00',
#     'caseCourt': '邯郸市复兴区人民法院'},
#    {'caseId': '41994398',
#     'caseTitle': '安阳振动器有限责任公司与邯钢集团邯宝钢铁有限公司买卖合同纠纷一审民事裁定书',
#     'caseCode': '（2016）冀0404民初1260号',
#     'uri': '0/2/2060/3f38cd2f-f8fc-40de-88b5-c5aaddf3a576.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 23680.0,
#     'caseDate': '2016-08-17 00:00:00',
#     'caseCourt': '邯郸市复兴区人民法院'},
#    {'caseId': '49333766',
#     'caseTitle': '德阳立达机电设备有限公司与邯钢集团邯宝钢铁有限公司买卖合同纠纷一审民事裁定书',
#     'caseCode': '（2017）冀0404民初658号',
#     'uri': '0/2/3852/7db35339-d895-4de7-8309-cadfbfd2e4cb.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 6067142.0,
#     'caseDate': '2017-07-05 00:00:00',
#     'caseCourt': '邯郸市复兴区人民法院'},
#    {'caseId': '59076883',
#     'caseTitle': '沈阳远大铝业集团有限公司与邯钢集团邯宝钢铁有限公司买卖合同纠纷一审民事裁定书',
#     'caseCode': '（2018）冀0404民初297号',
#     'uri': '0/3/2135/b79b1713-2525-41f6-b6f6-9107db551d59.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 36800.0,
#     'caseDate': '2018-03-26 00:00:00',
#     'caseCourt': '邯郸市复兴区人民法院'},
#    {'caseId': '59076493',
#     'caseTitle': '大连奈尔孙机电设备有限公司与邯钢集团邯宝钢铁有限公司买卖合同纠纷一审民事裁定书',
#     'caseCode': '（2018）冀0404民初84号',
#     'uri': '0/3/2134/088da147-07ea-4711-ad22-88be17652377.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 28560.0,
#     'caseDate': '2018-01-25 00:00:00',
#     'caseCourt': '邯郸市复兴区人民法院'},
#    {'caseId': '9049862',
#     'caseTitle': '原告鞍山市格林环保设备有限公司诉被告邯钢集团邯宝钢铁设备有限公司买卖合同纠纷一案民事一审裁定书',
#     'caseCode': '（2015）海民二初字第384号',
#     'uri': '0/2209/1798/d070efea-2b9d-4073-afbf-dabeaab66a8b.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 98800.0,
#     'caseDate': '2015-05-13 00:00:00',
#     'caseCourt': '海城市人民法院'},
#    {'caseId': '9049841',
#     'caseTitle': '原告鞍山市格林环保设备有限公司诉被告邯钢集团邯宝钢铁有限公司买卖合同纠纷案民事一审裁定书',
#     'caseCode': '（2015）海民二初字第383号',
#     'uri': '0/2209/1777/afe309cc-2855-41d2-9468-c8b6adeacd34.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 748000.0,
#     'caseDate': '2015-05-13 00:00:00',
#     'caseCourt': '海城市人民法院'},
#    {'caseId': '9049836',
#     'caseTitle': '原告鞍山市格林环保设备有限公司诉被告邯钢集团邯宝钢铁有限公司买卖合同纠纷一案民事一审裁定书',
#     'caseCode': '（2015）海民二初字第00385-1号',
#     'uri': '0/2209/1772/ff40f92d-4c97-479f-a922-203c8ff9f002.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 782200.0,
#     'caseDate': '2015-05-13 00:00:00',
#     'caseCourt': '海城市人民法院'},
#    {'caseId': '9049838',
#     'caseTitle': '原告鞍山市格林环保设备有限公司诉被告邯钢集团邯宝钢铁有限公司买卖合同纠纷案民事一审判决书',
#     'caseCode': '（2015）海民二初字第382号',
#     'uri': '0/2209/1774/f3fc64bc-66d2-423e-8662-a71ac6eebe25.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 98800.0,
#     'caseDate': '2015-05-13 00:00:00',
#     'caseCourt': '海城市人民法院'},
#    {'caseId': '10674514',
#     'caseTitle': '济南冶金化工设备有限公司与邯钢集团邯宝钢铁有限公司承揽合同纠纷一审民事裁定书',
#     'caseCode': '（2013）长商初字第739号',
#     'uri': '0/2606/338/d4f27cf8-9446-4d84-b705-020a76b4d9f6.html',
#     'category': '承揽合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 362800.0,
#     'caseDate': '2014-03-14 00:00:00',
#     'caseCourt': '济南市长清区人民法院'},
#    {'caseId': '19157065',
#     'caseTitle': '河南省中亿建设集团有限公司与邯郸钢铁集团有限责任公司、邯钢集团邯宝钢铁有限公司建设工程施工合同纠纷一审民事裁定书',
#     'caseCode': '（2015）复民初字第819号',
#     'uri': '1/581/73/be72506e-c6f2-4456-b910-2edd53bd5c1d.html',
#     'category': '建设工程施工合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 11583333.0,
#     'caseDate': '2015-09-23 00:00:00',
#     'caseCourt': '邯郸市复兴区人民法院'},
#    {'caseId': '19161540',
#     'caseTitle': '河南省中亿建设集团有限公司与邯郸钢铁集团有限责公司、邯钢集团邯宝钢铁有限公司建设工程施工合同纠纷一审民事裁定书',
#     'caseCode': '（2015）复民初字第820号',
#     'uri': '1/582/452/9c557bda-b927-489d-beaa-f0c8c16b7320.html',
#     'category': '建设工程施工合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 8436000.0,
#     'caseDate': '2015-09-23 00:00:00',
#     'caseCourt': '邯郸市复兴区人民法院'},
#    {'caseId': '32725427',
#     'caseTitle': '平安银行股份有限公司北京万柳支行申请邯郸市中发物资有限公司等申请诉前财产保全一案',
#     'caseCode': '（2016）京04财保24号',
#     'uri': '0/1/3893/ad9d8db2-fc59-4463-90e2-a8aa873ff2a0.html',
#     'category': '金融借款合同纠纷',
#     'caseType': 1,
#     'role': 2,
#     'amount': 50000000.0,
#     'caseDate': '2016-06-02 00:00:00',
#     'caseCourt': '北京市第四中级人民法院'},
#    {'caseId': '32897802',
#     'caseTitle': '杭州电缆股份有限公司与邯钢集团邯宝钢铁有限公司管辖裁定书',
#     'caseCode': '（2016）浙0111民初2575号之一',
#     'uri': '0/1/3935/36110f73-38a4-45d8-83f6-696b8756345e.html',
#     'category': '管辖权异议',
#     'caseType': 1,
#     'role': 1,
#     'amount': -3.0,
#     'caseDate': '2016-05-17 00:00:00',
#     'caseCourt': '杭州市富阳区人民法院'},
#    {'caseId': '33727916',
#     'caseTitle': '合肥天鹅制冷科技有限公司与邯钢集团邯宝钢铁有限公司买卖合同纠纷一审民事裁定书',
#     'caseCode': '（2016）皖0111民初7321号',
#     'uri': '0/2/42/fbb2b498-ece6-47ad-b358-1a107f61a6d8.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': -1.0,
#     'caseDate': '2016-09-21 00:00:00',
#     'caseCourt': '合肥市包河区人民法院'},
#    {'caseId': '41711655',
#     'caseTitle': '合肥天鹅制冷科技有限公司与邯钢集团邯宝钢铁有限公司买卖合同纠纷一审民事裁定书',
#     'caseCode': '（2016）皖0111民初7321-1号',
#     'uri': '0/2/1991/3ad7ce67-241e-4fcf-a6aa-78f591cbf093.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 499066.0,
#     'caseDate': '2016-11-21 00:00:00',
#     'caseCourt': '合肥市包河区人民法院'},
#    {'caseId': '44957123',
#     'caseTitle': '威台机械(上海)有限公司与邯钢集团邯宝钢铁有限公司买卖合同纠纷一审民事裁定书',
#     'caseCode': '（2017）沪0114民初8904号',
#     'uri': '0/2/2783/203d17db-3b38-467d-827e-612cc923a875.html',
#     'category': '买卖合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 2438625.0,
#     'caseDate': '2017-06-26 00:00:00',
#     'caseCourt': '上海市嘉定区人民法院'},
#    {'caseId': '50931366',
#     'caseTitle': '韩习雷与淄博连晟泵业有限公司债权转让合同纠纷一审民事判决书',
#     'caseCode': '（2017）冀0427民初499号',
#     'uri': '0/3/146/fa131c8e-0d0b-4dc4-9b5d-dd2522dc6ba1.html',
#     'category': '债权转让合同纠纷',
#     'caseType': 1,
#     'role': 2,
#     'amount': 10800.0,
#     'caseDate': '2017-04-18 00:00:00',
#     'caseCourt': '磁县人民法院'},
#    {'caseId': '53672342',
#     'caseTitle': '刘振与邯钢集团邯宝钢铁有限公司债权转让合同纠纷一审民事判决书',
#     'caseCode': '（2017）冀0404民初1297号',
#     'uri': '0/3/815/44117649-bd06-4977-82c5-90c7f6b6e516.html',
#     'category': '债权转让合同纠纷',
#     'caseType': 1,
#     'role': 1,
#     'amount': 4473149.0,
#     'caseDate': '2017-10-31 00:00:00',
#     'caseCourt': '邯郸市复兴区人民法院'},
#    {'caseId': '53671529',
#     'caseTitle': '衡水奥诺工矿机械设备有限公司、邯郸市邯钢霞光实业公司液压附件厂买卖合同纠纷执行实施类执行裁定书',
#     'caseCode': '（2017）冀0404执699-2号',
#     'uri': '0/3/815/e0ea6b45-729d-46ad-bb7f-786b69ca5b8b.html',
#     'category': '执行案件',
#     'caseType': 1,
#     'role': 2,
#     'amount': -2.0,
#     'caseDate': '2017-10-28 00:00:00',
#     'caseCourt': '邯郸市复兴区人民法院'}]}}

# %%
requests.get('http://www.51djl.com/document/0/2/3852/7db35339-d895-4de7-8309-cadfbfd2e4cb.html', headers=HEADER).text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="zh-CN">\n\t<head>\n\t\t<title>德阳立达机电设备有限公司与邯钢集团邯宝钢铁有限公司买卖合同纠纷一审民事裁定书-点击律</title>\n\t\t<meta name="Keywords" Content="点击律,法律服务,诉讼服务,合同,智能合同,律师,律师信息查询,企业法律信息查询,诉讼数据">\n\t\t<meta name="description" content="点击律以领先的大数据技术和覆盖全国的律师合作网络，致力于解决企业实际经营中遇到的法律痛点，以极低的成本、卓越的品质提供诉讼服务、做合同等专业法律服务，并提供律师执业信息、企业诉讼信息费提查询服务。点击律，让优质法律服务不再难！">\n\t\t\n<meta charset="UTF-8">\n<meta http-equiv="X-UA-Compatible" content="IE=Edge">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<base href="http://www.51djl.com:80/">\n<link href="http://www.51djl.com:80/global/bootstrap/css/bootstrap.min.css" rel="stylesheet">\n<link href="http://www.51djl.com:80/global/js/addon/datetimepicker/jquery.datetimepicker.min.css" rel="stylesheet">\n<link href="http://www.51djl.com:80/global/js/addon/pagination/pagination.min.css" rel="stylesheet">\n<link href="http://www.51djl.com:80/global/css/layout.css" rel="stylesheet">\n<link href="http://www.51djl.com:80/global/css/headTop.css" rel="stylesheet">\n<!--[if lt IE 9]>\n<script src="http://www.51djl.com:80/global/bootstrap/js/html5shiv.min.js"></script>\n<script src="http://www.51djl.com:80/global/bootstrap/js/respond.min.js"></script>\n<![endif]-->\n\n<script charset="UTF-8" src="http://www.51djl.com:80/global/js/jquery-1.11.3.min.js"></script>\n<script charset="UTF-8" src="http://www.51djl.com:80/global/js/area.js"></script>\n<script charset="UTF-8" src="http://www.51djl.com:80/global/bootstrap/js/bootstrap.min.js"></script>\n<script charset="UTF-8" src="http://www.51djl.com:80/global/js/addon/datetimepicker/jquery.datetimepicker.min.js"></script>\n<script charset="UTF-8" src="http://www.51djl.com:80/global/js/d3.min.js"></script>\n<script charset="UTF-8" src="http://www.51djl.com:80/global/js/addon/validate/jquery.form.min.js"></script>\n<script charset="UTF-8" src="http://www.51djl.com:80/global/js/addon/validate/jquery.validate.min.js"></script>\n<script charset="UTF-8" src="http://www.51djl.com:80/global/js/addon/validate/messages_zh.min.js"></script>\n<script charset="UTF-8" src="http://www.51djl.com:80/global/js/addon/validate/jquery.validate-extend.js"></script>\n<script charset="UTF-8" src="http://www.51djl.com:80/global/js/addon/jquery.cookie.min.js"></script>\n<script charset="UTF-8" src="http://www.51djl.com:80/global/js/addon/pagination/jquery.pagination.js"></script>\n<script charset="UTF-8" src="http://www.51djl.com:80/mobile/lib/device.min.js"></script>\n<script charset="UTF-8" src="http://www.51djl.com:80/mobile/lib/base64encoder.js"></script>\n<script charset="UTF-8" src="http://www.51djl.com:80/mobile/js/redirect.js?v=1.0.1"></script>\n<script charset="UTF-8" src="http://www.51djl.com:80/global/js/utility.js?v=1.0.1"></script>\n<script type="text/javascript">\nvar ctx = "http://www.51djl.com:80/";\nvar fileDomain = "http://pic.51djl.com/";\nvar loginStatus = true;\nvar lookCorpSample = false;\n</script>\n<script charset="UTF-8" src="http://www.51djl.com:80/global/js/global.js"></script>\n\n\t\t<style type="text/css">\n\t\t#content {width: 1200px; margin: 0 auto; background: #fff; padding: 0px 60px;}\n\t\t.detail .casetitle {font-size: 1.2em; text-align: center; font-weight: bold; line-height: 30px; border-bottom: 1px solid #ddd; padding: 20px 0; margin: 0;}\n\t\t.detail .casecourt {font-size: 1.4em; text-align: center; padding-top: 20px; margin: 0;}\n\t\t.detail [class^=\'textcategory\'] {font-size: 1.4em; text-align: center; padding-top: 20px; margin: 0;}\n\t\t.detail .casecode {text-align: right; padding-top: 10px; font-weight: bold;}\n\t\t.detail .section {text-indent: 2em; padding: 10px 0;}\n\t\t.detail .judge {text-align: right; padding-bottom: 20px;}\n\t\t.notice {margin-bottom:30px}\n\t\t.notice hr {margin-top: 0px;}\n\t\t.notice .title {text-align: center;font-weight: bold;margin-bottom: 10px;font-size: 16px;}\n\t\t</style>\n\t</head>\n\t<body>\n\t\t\n\n<div ...
